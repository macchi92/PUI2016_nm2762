# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import math
import geopy

import matplotlib.pyplot as plt
import shapely
# %matplotlib inline

from geopy.distance import vincenty
from geopy.distance import great_circle

from shapely.geometry import Point

# %% [markdown]
# ## Here I get the shapefile I need.

# %%
bikestation = gpd.read_file('Bike sharing/stazioni/BIKE_SH.shp')
metro = gpd.read_file('metro/fermate/MM_FERM.shp')
milan = gpd.read_file('Milan_shape/milan.shp')

# %% [markdown]
# # Changing coordinates

# %%
bikestation = bikestation.to_crs(epsg=26591)
metro = metro.to_crs(epsg=26591)
milan = milan.to_crs(epsg=26591)

# %% [markdown]
# # Define some usefull function

# %%
def buffer_merged_polygon(point, radius):
    point=gpd.GeoDataFrame(point.buffer(radius))
    point.columns=['geometry']
    return point.unary_union

# %%
def intersection_polygon_shape(shape,polygon):
    intersection=shape.geometry.intersection(polygon)
    intersection=gpd.GeoDataFrame(intersection)
    intersection.columns=['geometry']
    return intersection

# %%
def difference_shape_shape(A,MinusB):
    difference=A.difference(MinusB)
    difference.columns=['geometry']
    return difference

# %% [markdown]
# # Find the area I need. Buffer 2500m around metro station

# %%
metro_buffer_2500=buffer_merged_polygon(metro,2500)

# %%
milan_2500=intersection_polygon_shape(milan,metro_buffer_2500)

# %%
milan_2500.plot()

# %% [markdown]
# # Find the area we are not interested in

# %%
notbikeablemilan=difference_shape_shape(milan,milan_2500)
# Out:
# /Users/nicolamacchitella/anaconda/lib/python3.5/site-packages/geopandas/base.py:30: UserWarning: GeoSeries crs mismatch: {'no_defs': True, 'init': 'epsg:26591'} and None
#   other.crs))

# %%
notbikeablemilan.plot()

# %% [markdown]
# # Find the area of those who can walk to the metro

# %%
metro_buffer_300=metro_buffer=buffer_merged_polygon(metro,300)

# %%
milan_300=intersection_polygon_shape(milan,metro_buffer_300)

# %%
milan_300.plot()

# %%
fig, ax = plt.subplots(figsize=(20, 20))

complete.plot()

# %%
type(metro.plot())
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ## Change the coordinates system
# ## Clean the data

# %%
def getX(pt):
    return pt.x
def getY(pt):
    return pt.y

# %%
centroidlist_x=map(getX,milan['geometry'].centroid)
centroidlist_y=map(getY,milan['geometry'].centroid)

# %%
milan['x']=list(centroidlist_x)
milan['y']=list(centroidlist_y)

# %% [markdown]
# # Get the shapefile
# # Change the coordinates system
# # Clean the data

# %%
milan = gpd.read_file('Milan_shape/milan.shp')

# %%
milan.drop(['x', 'y'] , axis=1, inplace=True)

# %%
milan.drop(['ACE',  'PRO_COM', 'SEZ', 'SEZ2011',
        'TIPO_LOC',  'mappa2',
       'mappa2bis'], axis=1, inplace=True)

# %%
milan.head(n=1)
# Out:
#    ACE  OBJECTID  POP_2010  PRO_COM  SEZ       SEZ2011   SHAPE_AREA  \
# 0  1.0     49010      70.0    15146  236  1.514600e+11  8061.468253
#
#     SHAPE_LEN  TIPO_LOC                                           geometry  \
# 0  449.226698         1  POLYGON ((1514122.149438964 5034191.777491422,...
#
#    mappa2  mappa2bis             x             y
# 0       3        5.0  1.514148e+06  5.034196e+06

# %%
milan.drop(['ACE',  'PRO_COM', 'SEZ', 'SEZ2011',
        'TIPO_LOC',  'mappa2',
       'mappa2bis'], axis=1, inplace=True)

# %%
holes=gpd.GeoDataFrame()

# %%
milan=milan.append({'geometry': Point(milan['x'][0],milan['y'][0]).buffer(2000)}, ignore_index=True )

# %%
milan['geometry'][0].buffer(200)

# %%
milan.plot(figsize=(30,30))

# %%
ax = milan.plot(color='grey');

Point(milan['x'][0],milan['y'][0]).buffer(200).plot(ax=ax, color='green');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-98221e996077> in <module>()
#       1 ax = milan.plot(color='grey');
#       2
# ----> 3 Point(milan['x'][0],milan['y'][0]).buffer(200).plot(ax=ax, color='green');
#
# AttributeError: 'Polygon' object has no attribute 'plot'

# %%
fig, ax = plt.subplots(figsize=(12, 10))


milan.plot(ax=ax, color = 'grey')
ax.scatter(milan['x'][0],milan['y'][0], s = 2000)

# %%
milan['geometry'][0].buffer(0)

# %%
#milan['geometry'].intersects(milan['geometry'][0].buffer(0))
gpd.overlay(milan, a, how='intersection')

# %%
len(holes)
# Out:
# 0

# %%
fig, ax = plt.subplots(figsize=(20,20))

# set aspect to equal. This is done automatically
# when using *geopandas* plot on it's own, but not when
# working with pyplot directly.
ax.set_aspect('equal')

milan.plot(ax=ax, color='white')
Point().plot(ax=ax, marker='o', color='red', markersize=5)
Out[18]: <matplotlib.axes._subplots.AxesSubplot at 0x118d809e8>

In [19]: plt.show();
